# %% [markdown]
# # Evaluate the Prompt U-Net models against each other
# ### This evaluation run uses FLARE_2022 and HaNSeg

# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), '..', '..'))

from evaluation.eval_prompt_unet.eval_p_unet_pipeline import PromptUNetTester

dimensions = ['x', 'y', 'z'] 
offsets = [30]
models = [
    'p_unet_21.keras',
    'p_unet_300.keras',
    'p_unet_311.keras',
    'p_unet_312.keras',
    'p_unet_313.keras',
]

max_data_points = 750 # must be large enough, for datagen to capture more unique tasks and axis 
models_dir = "training/"

# %% [markdown]
# ### 1. Evaluate on HanSeg (MRI)

# %%
print("--- RUNNING HANSEG (MRI) EVALUATION ---")
dataset_path = ["data/test_data/han_seg_mri.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop
results_hanseg = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING HANSEG (MRI) EVALUATION ---
# [INFO] CPU detected — will force float32 compute policy per model.
#
# Loading NPZ dataset(s)…
# Loaded 42 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\han_seg_mri.npz
#
# Final dataset size: 42 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 9 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 32.1 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.632
# Testing p_unet_300.keras... Done. Took 34.4 seconds.
# [p_unet_300.keras] -> Avg Dice: 0.602
# Testing p_unet_311.keras... Done. Took 44.1 seconds.
# [p_unet_311.keras] -> Avg Dice: 0.593
# Testing p_unet_312.keras... Done. Took 42.6 seconds.
# [p_unet_312.keras] -> Avg Dice: 0.599
# Testing p_unet_313.keras... Done. Took 43.9 seconds.
# [p_unet_313.keras] -> Avg Dice: 0.619
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.927
# Dice: 0.840
#
#
# >> Visualizing predictions for: p_unet_300.keras (Threshold: 0.5)
# Dice: 0.948
# Dice: 0.844
#
#
# >> Visualizing predictions for: p_unet_311.keras (Threshold: 0.5)
# Dice: 0.937
# Dice: 0.867
#
#
# >> Visualizing predictions for: p_unet_312.keras (Threshold: 0.5)
# Dice: 0.937
# Dice: 0.905
#
#
# >> Visualizing predictions for: p_unet_313.keras (Threshold: 0.5)
# Dice: 0.940
# Dice: 0.900

# %% [markdown]
# ### 2. Evaluate on HanSeg (CT)

# %%
print("--- RUNNING HANSEG (CT) EVALUATION ---")
dataset_path = ["data/test_data/han_seg_ct.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop 
results_hanseg = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING HANSEG (CT) EVALUATION ---
# [INFO] CPU detected — will force float32 compute policy per model.
#
# Loading NPZ dataset(s)…
# Loaded 42 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\han_seg_ct.npz
#
# Final dataset size: 42 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 41 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 33.5 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.626
# Testing p_unet_300.keras... Done. Took 34.4 seconds.
# [p_unet_300.keras] -> Avg Dice: 0.631
# Testing p_unet_311.keras... Done. Took 43.3 seconds.
# [p_unet_311.keras] -> Avg Dice: 0.668
# Testing p_unet_312.keras... Done. Took 46.7 seconds.
# [p_unet_312.keras] -> Avg Dice: 0.655
# Testing p_unet_313.keras... Done. Took 46.9 seconds.
# [p_unet_313.keras] -> Avg Dice: 0.668
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.156
# Dice: 0.695
#
#
# >> Visualizing predictions for: p_unet_300.keras (Threshold: 0.5)
# Dice: 0.000
# Dice: 0.854
#
#
# >> Visualizing predictions for: p_unet_311.keras (Threshold: 0.5)
# Dice: 0.000
# Dice: 0.799
#
#
# >> Visualizing predictions for: p_unet_312.keras (Threshold: 0.5)
# Dice: 0.000
# Dice: 0.871
#
#
# >> Visualizing predictions for: p_unet_313.keras (Threshold: 0.5)
# Dice: 0.000
# Dice: 0.836

# %% [markdown]
# ### 3. Evaluate on FLARE (CT)

# %%
print("--- RUNNING FLARE (CT) EVALUATION ---")
dataset_path = ["data/test_data/FLARE_2022.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop
results_flare = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING FLARE (CT) EVALUATION ---
# [INFO] CPU detected — will force float32 compute policy per model.
#
# Loading NPZ dataset(s)…
# Loaded 50 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\FLARE_2022.npz
#
# Final dataset size: 50 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 15 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 30.9 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.790
# Testing p_unet_300.keras... Done. Took 34.2 seconds.
# [p_unet_300.keras] -> Avg Dice: 0.884
# Testing p_unet_311.keras... Done. Took 44.9 seconds.
# [p_unet_311.keras] -> Avg Dice: 0.886
# Testing p_unet_312.keras... Done. Took 43.8 seconds.
# [p_unet_312.keras] -> Avg Dice: 0.887
# Testing p_unet_313.keras... Done. Took 45.5 seconds.
# [p_unet_313.keras] -> Avg Dice: 0.890
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.755
# Dice: 0.754
#
#
# >> Visualizing predictions for: p_unet_300.keras (Threshold: 0.5)
# Dice: 0.901
# Dice: 0.871
#
#
# >> Visualizing predictions for: p_unet_311.keras (Threshold: 0.5)
# Dice: 0.833
# Dice: 0.883
#
#
# >> Visualizing predictions for: p_unet_312.keras (Threshold: 0.5)
# Dice: 0.916
# Dice: 0.858
#
#
# >> Visualizing predictions for: p_unet_313.keras (Threshold: 0.5)
# Dice: 0.895
# Dice: 0.879

# %% [markdown]
# ### 4. Evaluate on BraTS GLI (MRI)

# %%
print("--- RUNNING BraTS (MRI) EVALUATION ---")
dataset_path = ["data/test_data/BraTS_GLI_t1c.npz", "data/test_data/BraTS_GLI_t1n.npz", "data/test_data/BraTS_GLI_t2f.npz", "data/test_data/BraTS_GLI_t2w.npz",]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop
results_flare = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING BraTS (MRI) EVALUATION ---
# [INFO] CPU detected — will force float32 compute policy per model.
#
# Loading NPZ dataset(s)…
# Loaded 271 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\BraTS_GLI_t1c.npz
# Loaded 271 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\BraTS_GLI_t1n.npz
# Loaded 271 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\BraTS_GLI_t2f.npz
# Loaded 271 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\BraTS_GLI_t2w.npz
#
# Final dataset size: 1084 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 2 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 31.8 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.568
# Testing p_unet_300.keras... Done. Took 34.5 seconds.
# [p_unet_300.keras] -> Avg Dice: 0.537
# Testing p_unet_311.keras... Done. Took 45.0 seconds.
# [p_unet_311.keras] -> Avg Dice: 0.497
# Testing p_unet_312.keras... Done. Took 43.8 seconds.
# [p_unet_312.keras] -> Avg Dice: 0.496
# Testing p_unet_313.keras... Done. Took 45.9 seconds.
# [p_unet_313.keras] -> Avg Dice: 0.525
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.806
# Dice: 0.421
#
#
# >> Visualizing predictions for: p_unet_300.keras (Threshold: 0.5)
# Dice: 0.846
# Dice: 0.636
#
#
# >> Visualizing predictions for: p_unet_311.keras (Threshold: 0.5)
# Dice: 0.812
# Dice: 0.662
#
#
# >> Visualizing predictions for: p_unet_312.keras (Threshold: 0.5)
# Dice: 0.632
# Dice: 0.640
#
#
# >> Visualizing predictions for: p_unet_313.keras (Threshold: 0.5)
# Dice: 0.848
# Dice: 0.406

# %% [markdown]
# ### 5. Evaluate on BraTS MEN RT (MRI)

# %%
print("--- RUNNING BraTS (MRI) EVALUATION ---")
dataset_path = ["data/test_data/BraTS_MEN_RT.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop
results_flare = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING BraTS (MRI) EVALUATION ---
# [INFO] CPU detected — will force float32 compute policy per model.
#
# Loading NPZ dataset(s)…
# Loaded 250 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\BraTS_MEN_RT.npz
#
# Final dataset size: 250 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 5 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 32.6 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.729
# Testing p_unet_300.keras... Done. Took 35.6 seconds.
# [p_unet_300.keras] -> Avg Dice: 0.861
# Testing p_unet_311.keras... Done. Took 45.2 seconds.
# [p_unet_311.keras] -> Avg Dice: 0.868
# Testing p_unet_312.keras... Done. Took 44.9 seconds.
# [p_unet_312.keras] -> Avg Dice: 0.872
# Testing p_unet_313.keras... Done. Took 45.0 seconds.
# [p_unet_313.keras] -> Avg Dice: 0.863
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.704
# Dice: 0.875
#
#
# >> Visualizing predictions for: p_unet_300.keras (Threshold: 0.5)
# Dice: 0.896
# Dice: 0.959
#
#
# >> Visualizing predictions for: p_unet_311.keras (Threshold: 0.5)
# Dice: 0.915
# Dice: 0.953
#
#
# >> Visualizing predictions for: p_unet_312.keras (Threshold: 0.5)
# Dice: 0.944
# Dice: 0.969
#
#
# >> Visualizing predictions for: p_unet_313.keras (Threshold: 0.5)
# Dice: 0.929
# Dice: 0.951
