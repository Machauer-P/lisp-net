# %% [markdown]
# # Evaluate the Prompt U-Net models against each other
# ### This evaluation run uses FLARE_2022 and HaNSeg

# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), '..', '..'))

from evaluation.eval_prompt_unet.eval_p_unet_pipeline import PromptUNetTester

dimensions = ['x', 'y', 'z'] 
offsets = [5, 12, 30]
models = [
    'p_unet_21.keras',
    'p_unet_272.keras',
    'p_unet_273.keras',
    'p_unet_282.keras',
    'p_unet_283.keras',
    'p_unet_292.keras'
]

max_data_points = 1500 # must be large enough, for datagen to capture more unique tasks and axis 
models_dir = "training/"

# %% [markdown]
# ### 1. Evaluate on HanSeg (MRI)

# %%
print("--- RUNNING HANSEG (MRI) EVALUATION ---")
dataset_path = ["data/test_data/han_seg_mri.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop
results_hanseg = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING HANSEG (MRI) EVALUATION ---
#
# Loading NPZ dataset(s)…
# Loaded 42 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\han_seg_mri.npz
#
# Final dataset size: 42 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 5 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 35 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 167.6 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.805
# Testing p_unet_272.keras... Done. Took 193.2 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.777
# Testing p_unet_273.keras... Done. Took 182.0 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.771
# Testing p_unet_282.keras... Done. Took 231.7 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.781
# Testing p_unet_283.keras... Done. Took 245.1 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.780
# Testing p_unet_292.keras... Done. Took 287.5 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.784
#
# ==================================================
#    EVALUATING OFFSET: 12 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 49 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 168.8 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.729
# Testing p_unet_272.keras... Done. Took 183.3 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.702
# Testing p_unet_273.keras... Done. Took 175.6 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.691
# Testing p_unet_282.keras... Done. Took 229.2 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.703
# Testing p_unet_283.keras... Done. Took 255.3 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.694
# Testing p_unet_292.keras... Done. Took 272.3 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.703
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 179 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 198.1 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.646
# Testing p_unet_272.keras... Done. Took 192.9 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.631
# Testing p_unet_273.keras... Done. Took 177.2 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.619
# Testing p_unet_282.keras... Done. Took 266.1 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.636
# Testing p_unet_283.keras... Done. Took 266.0 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.622
# Testing p_unet_292.keras... Done. Took 274.9 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.603
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.722
# Dice: 0.858
#
#
# >> Visualizing predictions for: p_unet_272.keras (Threshold: 0.5)
# Dice: 0.764
# Dice: 0.789
#
#
# >> Visualizing predictions for: p_unet_273.keras (Threshold: 0.5)
# Dice: 0.869
# Dice: 0.839
#
#
# >> Visualizing predictions for: p_unet_282.keras (Threshold: 0.5)
# Dice: 0.921
# Dice: 0.846
#
#
# >> Visualizing predictions for: p_unet_283.keras (Threshold: 0.5)
# Dice: 0.884
# Dice: 0.823
#
#
# >> Visualizing predictions for: p_unet_292.keras (Threshold: 0.5)
# Dice: 0.919
# Dice: 0.816

# %% [markdown]
# ### 2. Evaluate on HanSeg (CT)

# %%
print("--- RUNNING HANSEG (CT) EVALUATION ---")
dataset_path = ["data/test_data/han_seg_ct.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop 
results_hanseg = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING HANSEG (CT) EVALUATION ---
#
# Loading NPZ dataset(s)…
# Loaded 42 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\han_seg_ct.npz
#
# Final dataset size: 42 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 5 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 149 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 186.5 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.809
# Testing p_unet_272.keras... Done. Took 184.3 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.768
# Testing p_unet_273.keras... Done. Took 184.5 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.804
# Testing p_unet_282.keras... Done. Took 251.5 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.816
# Testing p_unet_283.keras... Done. Took 247.5 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.802
# Testing p_unet_292.keras... Done. Took 240.9 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.814
#
# ==================================================
#    EVALUATING OFFSET: 12 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 173 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 149.2 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.719
# Testing p_unet_272.keras... Done. Took 161.5 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.697
# Testing p_unet_273.keras... Done. Took 165.4 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.721
# Testing p_unet_282.keras... Done. Took 252.3 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.731
# Testing p_unet_283.keras... Done. Took 245.8 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.719
# Testing p_unet_292.keras... Done. Took 252.0 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.729
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 448 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 201.2 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.643
# Testing p_unet_272.keras... Done. Took 196.0 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.649
# Testing p_unet_273.keras... Done. Took 204.3 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.664
# Testing p_unet_282.keras... Done. Took 293.1 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.675
# Testing p_unet_283.keras... Done. Took 256.4 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.660
# Testing p_unet_292.keras... Done. Took 254.2 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.677
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.075
# Dice: 0.855
#
#
# >> Visualizing predictions for: p_unet_272.keras (Threshold: 0.5)
# Dice: 0.536
# Dice: 0.847
#
#
# >> Visualizing predictions for: p_unet_273.keras (Threshold: 0.5)
# Dice: 0.502
# Dice: 0.852
#
#
# >> Visualizing predictions for: p_unet_282.keras (Threshold: 0.5)
# Dice: 0.690
# Dice: 0.825
#
#
# >> Visualizing predictions for: p_unet_283.keras (Threshold: 0.5)
# Dice: 0.176
# Dice: 0.808
#
#
# >> Visualizing predictions for: p_unet_292.keras (Threshold: 0.5)
# Dice: 0.000
# Dice: 0.849

# %% [markdown]
# ### 3. Evaluate on FLARE (CT)

# %%
print("--- RUNNING FLARE (CT) EVALUATION ---")
dataset_path = ["data/test_data/FLARE_2022.npz"]

# Initialize tester
tester = PromptUNetTester(
    dataset_path=dataset_path,
    models_dir=models_dir,
    max_data_points=max_data_points
)

# Execute full validation loop
results_flare = tester.run_pipeline(
    dimensions=dimensions, 
    offsets=offsets, 
    models=models, 
    threshold=0.5, 
    num_visualize=2
)
# Out:
# --- RUNNING FLARE (CT) EVALUATION ---
#
# Loading NPZ dataset(s)…
# Loaded 50 PIDs from C:\Users\Paul\Desktop\Studium\prompt-unet\data\test_data\FLARE_2022.npz
#
# Final dataset size: 50 patients.
#
#
# ==================================================
#    EVALUATING OFFSET: 5 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 30 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 66.4 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.919
# Testing p_unet_272.keras... Done. Took 66.0 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.935
# Testing p_unet_273.keras... Done. Took 66.9 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.939
# Testing p_unet_282.keras... Done. Took 176.0 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.946
# Testing p_unet_283.keras... Done. Took 184.2 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.938
# Testing p_unet_292.keras... Done. Took 176.3 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.952
#
# ==================================================
#    EVALUATING OFFSET: 12 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 38 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 68.0 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.873
# Testing p_unet_272.keras... Done. Took 67.9 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.904
# Testing p_unet_273.keras... Done. Took 67.5 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.910
# Testing p_unet_282.keras... Done. Took 155.5 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.927
# Testing p_unet_283.keras... Done. Took 164.8 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.910
# Testing p_unet_292.keras... Done. Took 152.8 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.938
#
# ==================================================
#    EVALUATING OFFSET: 30 | AXIS: ['x', 'y', 'z']
# ==================================================
#
# Creating new Data Points ...
# It took 57 seconds
#
# --- [SECTION 1: METRICS] ---
# Testing p_unet_21.keras... Done. Took 69.1 seconds.
# [p_unet_21.keras] -> Avg Dice: 0.778
# Testing p_unet_272.keras... Done. Took 71.6 seconds.
# [p_unet_272.keras] -> Avg Dice: 0.805
# Testing p_unet_273.keras... Done. Took 72.2 seconds.
# [p_unet_273.keras] -> Avg Dice: 0.818
# Testing p_unet_282.keras... Done. Took 156.1 seconds.
# [p_unet_282.keras] -> Avg Dice: 0.846
# Testing p_unet_283.keras... Done. Took 154.4 seconds.
# [p_unet_283.keras] -> Avg Dice: 0.820
# Testing p_unet_292.keras... Done. Took 153.2 seconds.
# [p_unet_292.keras] -> Avg Dice: 0.882
#
# --- [SECTION 2: VISUALIZATIONS] ---
#
# >> Visualizing predictions for: p_unet_21.keras (Threshold: 0.5)
# Dice: 0.909
# Dice: 0.711
#
#
# >> Visualizing predictions for: p_unet_272.keras (Threshold: 0.5)
# Dice: 0.945
# Dice: 0.774
#
#
# >> Visualizing predictions for: p_unet_273.keras (Threshold: 0.5)
# Dice: 0.907
# Dice: 0.721
#
#
# >> Visualizing predictions for: p_unet_282.keras (Threshold: 0.5)
# Dice: 0.892
# Dice: 0.718
#
#
# >> Visualizing predictions for: p_unet_283.keras (Threshold: 0.5)
# Dice: 0.920
# Dice: 0.679
#
#
# >> Visualizing predictions for: p_unet_292.keras (Threshold: 0.5)
# Dice: 0.891
# Dice: 0.919
